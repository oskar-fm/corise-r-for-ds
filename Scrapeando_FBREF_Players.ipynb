# %% [markdown]
# <a href="https://colab.research.google.com/github/oskar-fm/corise-r-for-ds/blob/main/Scrapeando_FBREF_Players.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pip install git+http://github.com/griffisben/griffis_soccer_analysis.git
# Out:
# ...
#   Cloning http://github.com/griffisben/griffis_soccer_analysis.git to /tmp/pip-req-build-8p6t86al
#   Running command git clone --filter=blob:none --quiet http://github.com/griffisben/griffis_soccer_analysis.git /tmp/pip-req-build-8p6t86al
# ...
#   Resolved http://github.com/griffisben/griffis_soccer_analysis.git to commit 28742e57ed192d4e4499aa2c84306ece519bfb02
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 42.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 476.0/476.0 kB 23.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.1 MB/s eta 0:00:00
# ...
#   Created wheel for griffis_soccer_analysis: filename=griffis_soccer_analysis-1.0.2-py3-none-any.whl size=60730 sha256=757f91e08b85c809f1aaf3681c099a53fe3aee0236dc9f5b15d1019bb698dab4
# ...

# %%
from griffis_soccer_analysis.fbref_code import *

# %%
comps = ['La Liga 2']
ssns = ['2024']

scrape_fbref_next12_leagues_players(comps = comps, seasons = ssns)
# Out:
# Working on La Liga 2
# Done :) File named "Final FBRef Next 12 Leagues" is located at  //

# %%
df1 = pd.read_csv('../Final FBRef Next 12 Leagues.csv')
df1
# Out:
#                  Player  Nation    Pos        Squad       Comp  Age  Born  MP  \
# 0       Aarón Escandell  es ESP     GK       Oviedo  La Liga 2   29  1995   9
# 1          Aarón Martin       0     MF     Tenerife  La Liga 2    0     0   3
# 2           Aarón Ochoa  ie IRL  MF,FW       Málaga  La Liga 2   17  2007   7
# 3    Aboubacar Bassinga  ci CIV     FW  CD Mirandés  La Liga 2   19  2005   1
# 4           Adam Boayar  es ESP     FW        Elche  La Liga 2   19  2005   1
# ..                  ...     ...    ...          ...        ...  ...   ...  ..
# 523    Íñigo Sainz-Maza  es ESP  MF,FW  Racing Sant  La Liga 2   26  1998   7
# 524      Óscar Clemente  es ESP  FW,DF      Levante  La Liga 2   25  1999   2
# 525           Óscar Gil  es ESP  MF,DF    Castellón  La Liga 2   29  1995   9
# 526         Óscar Plano  es ESP  FW,MF        Elche  La Liga 2   33  1991   8
# 527        Óscar Sielva  es ESP     MF       Huesca  La Liga 2   33  1991   9
#
# ...

# %%
scrape_fbref_t5_leagues_players(season = '2024-2025')
# Out:
# Done :) Files are located at  ///Final FBRef 2024-2025.csv

# %%
df = pd.read_csv('../Final FBRef 2024-2025.csv')
df
# Out:
#                      Player   Nation    Pos            Squad  \
# 0     Aaron Ciammaglichella   it ITA     MF           Torino
# 1           Aaron Cresswell  eng ENG     DF         West Ham
# 2            Aaron Ramsdale  eng ENG     GK      Southampton
# 3         Aaron Wan-Bissaka  eng ENG  DF,MF         West Ham
# 4              Aarón Martín   es ESP     DF            Genoa
# ...                     ...      ...    ...              ...
# 2258             Ümit Akdag   ro ROU     DF         Toulouse
# 2259         Đorđe Petrović   rs SRB     GK       Strasbourg
# 2260         İlkay Gündoğan   de GER     MF  Manchester City
# 2261       Łukasz Fabiański   pl POL     GK         West Ham
# 2262       Łukasz Skorupski   pl POL     GK          Bologna
#
#                     Comp     Age  Born  MP  Starts    Min  ...  \
# 0             it Serie A      19  2005   1       0    1.0  ...
# 1     eng Premier League      34  1989   3       0   28.0  ...
# ...

# %%
df["Comp"].value_counts()
# Out:
# Comp
# it Serie A            489
# es La Liga            488
# eng Premier League    468
# fr Ligue 1            431
# de Bundesliga         387
# Name: count, dtype: int64
