# %% [markdown]
# <a href="https://colab.research.google.com/github/oskar-fm/corise-r-for-ds/blob/main/Scrapeando_FBREF_PlayersMLS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pip install git+http://github.com/griffisben/griffis_soccer_analysis.git
# Out:
# ...
#   Cloning http://github.com/griffisben/griffis_soccer_analysis.git to /tmp/pip-req-build-qedymaal
#   Running command git clone --filter=blob:none --quiet http://github.com/griffisben/griffis_soccer_analysis.git /tmp/pip-req-build-qedymaal
# ...
#   Resolved http://github.com/griffisben/griffis_soccer_analysis.git to commit 28742e57ed192d4e4499aa2c84306ece519bfb02
#   Preparing metadata (setup.py) ... done
# ...

# %%
from griffis_soccer_analysis.fbref_code import *

# %%
compsMLS = ['MLS']
ssnsMLS = ['2024']

scrape_fbref_next12_leagues_players(comps = compsMLS, seasons = ssnsMLS)
# Out:
# Working on MLS
# Done :) File named "Final FBRef Next 12 Leagues" is located at  //

# %%
df2 = pd.read_csv('../Final FBRef Next 12 Leagues.csv')
df2
# Out:
#                      Player  Nation    Pos             Squad Comp  Age  Born  \
# 0           Aaron Boupendza  ga GAB  FW,MF     FC Cincinnati  MLS   28  1996
# 1             Aaron Herrera  gt GUA     DF       D.C. United  MLS   27  1997
# 2                Aaron Long  us USA     DF              LAFC  MLS   32  1992
# 3            Abraham Romero  mx MEX     GK     Columbus Crew  MLS   26  1998
# 4    Adalberto Carrasquilla  pa PAN  FW,MF    Houston Dynamo  MLS   25  1998
# ..                      ...     ...    ...               ...  ...  ...   ...
# 846             Zavier Gozo  us USA     FW    Real Salt Lake  MLS   17  2007
# 847          Zorhan Bassong  ca CAN  DF,MF       Sporting KC  MLS   25  1999
# 848            Édier Ocampo  co COL  DF,FW  Vancouver W'caps  MLS   21  2003
# 849            Óscar Ustari  ar ARG     GK       Inter Miami  MLS   38  1986
# 850            Žan Kolmanič  si SVN  DF,FW            Austin  MLS   24  2000
#
# ...

# %%
df2.rename(columns={'pAdjAerialWinsPer90':'aerialwins'},inplace=True)
df2.head()
# Out:
#                    Player  Nation    Pos           Squad Comp  Age  Born  MP  \
# 0         Aaron Boupendza  ga GAB  FW,MF   FC Cincinnati  MLS   28  1996  14
# 1           Aaron Herrera  gt GUA     DF     D.C. United  MLS   27  1997  30
# 2              Aaron Long  us USA     DF            LAFC  MLS   32  1992  29
# 3          Abraham Romero  mx MEX     GK   Columbus Crew  MLS   26  1998   2
# 4  Adalberto Carrasquilla  pa PAN  FW,MF  Houston Dynamo  MLS   25  1998  28
#
#    Starts     Min  ...  aerialwins  pAdjAerialLossPer90  pAdjDrbPastAttPer90  \
# 0       5   553.0  ...   14.038877            21.598272             1.230281
# 1      29  2594.0  ...   32.075472            24.528302             1.898430
# 2      28  2374.0  ...   49.812030            13.157895             0.819498
# 3       2   134.0  ...    0.000000             0.000000             0.000000
# 4      26  2294.0  ...    8.578431            18.382353             1.827017
#
# ...

# %%
df2["Squad"].value_counts()
# Out:
# Squad
# Minnesota Utd          36
# St. Louis              35
# CF Montréal            34
# NE Revolution          34
# FC Dallas              34
# Charlotte              33
# Inter Miami            31
# Real Salt Lake         31
# Orlando City           31
# Portland Timbers       30
# SJ Earthquakes         30
# FC Cincinnati          29
# Columbus Crew          29
# Nashville SC           29
# Vancouver W'caps       29
# D.C. United            29
# Seattle Sounders FC    28
# Atlanta Utd            28
# Sporting KC            27
# Toronto FC             27
# Austin                 27
# NY Red Bulls           27
# Chicago Fire           27
# Houston Dynamo         27
# LAFC                   27
# Philadelphia Union     26
# LA Galaxy              26
# NYCFC                  25
# Colorado Rapids        25
# Name: count, dtype: int64

# %%
#scrape_fbref_t5_leagues_players(season = '2024-2025')

# %%
#df2 = pd.read_csv('../Final FBRef 2024-2025.csv')

# %%
#df["Comp"].value_counts()

# %%
# !pip install openpyxl

# %%
df2.to_excel('StatsPlayersMLS.xlsx', index=False)

# %%
from google.colab import files
files.download('StatsPlayersMLS.xlsx')
